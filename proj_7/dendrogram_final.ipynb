# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from sklearn import datasets
from sklearn.metrics import confusion_matrix

# %%
iris = datasets.load_iris()

# %%
plt.figure(figsize=(25, 10))
plt.title('Iris Hierarchical Clustering Dendrogram')
plt.xlabel('Species')
dendrogram = sch.dendrogram(sch.linkage(iris.data, method='single'))
plt.axhline(y=0.78, c='grey', lw=1, linestyle='dashed')
plt.savefig("single")

# %%
plt.figure(figsize=(25, 10))
plt.title('Iris Hierarchical Clustering Dendrogram')
plt.xlabel('Species')
dendrogram = sch.dendrogram(sch.linkage(iris.data, method='complete'))
plt.axhline(y=2.8, c='grey', lw=1, linestyle='dashed')
plt.savefig("complete")

# %%
plt.figure(figsize=(25, 10))
plt.title('Iris Hierarchical Clustering Dendrogram')
plt.xlabel('Species')
dendrogram = sch.dendrogram(sch.linkage(iris.data, method='average'))
plt.axhline(y=1.5, c='grey', lw=1, linestyle='dashed')
plt.savefig("average")

# %%
plt.figure(figsize=(25, 10))
plt.title('Iris Hierarchical Clustering Dendrogram')
plt.xlabel('Species')
dendrogram = sch.dendrogram(sch.linkage(iris.data, method='ward'))
plt.axhline(y=10, c='grey', lw=1, linestyle='dashed')
plt.savefig("ward")

# %%
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='single')
model.fit(iris.data)
labels = model.labels_
print(confusion_matrix(labels, iris.target))
# Out:
# [[ 0 50 48]
#  [50  0  0]
#  [ 0  0  2]]

# %%
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete')
model.fit(iris.data)
labels = model.labels_
print(confusion_matrix(labels, iris.target))
# Out:
# [[ 0 23 49]
#  [50  0  0]
#  [ 0 27  1]]

# %%
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='average')
model.fit(iris.data)
labels = model.labels_
print(confusion_matrix(labels, iris.target))
# Out:
# [[ 0 50 14]
#  [50  0  0]
#  [ 0  0 36]]

# %%
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
model.fit(iris.data)
labels = model.labels_
print(confusion_matrix(labels, iris.target))
# Out:
# [[ 0 49 15]
#  [50  0  0]
#  [ 0  1 35]]
